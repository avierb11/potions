# %% [markdown]
# # Run Hydrological Model
# This notebook is an example of how to construct a hydrological model in Potions and run the model forwards.

# %%
import potions as pt
import pandas as pd 
from pandas import DataFrame, Series
