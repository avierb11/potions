# %% [markdown]
# # Running a hydrologic model

# %% [markdown]
# The purpose of this notebook is to describe how the hydrologic model should run, from producing the forcing data to getting the output dataframe.

# %%
import numpy as np
from numpy.typing import NDArray
import pandas as pd 
from pandas import DataFrame, Series
from scipy.optimize import root_scalar
from model import Zone, Layer, Hillslope, Model, ForcingData

# %% [markdown]
# # Load Data

# %%
data_path: str = "../input/Sleepers_Results.txt"
data_df: DataFrame = pd.read_csv(data_path, delim_whitespace=True, index_col="Date", parse_dates=True)
data_df.head()
# Out:
# /tmp/ipykernel_12336/2477625894.py:2: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data_df: DataFrame = pd.read_csv(data_path, delim_whitespace=True, index_col="Date", parse_dates=True)
#                 Qsim   Qobs  Precipitation  ...        Q2  Qsim_rain  Qsim_snow
# Date                                        ...
# 2016-10-01  0.498270  0.138            0.0  ...  0.498270      0.496      0.002
# 2016-10-02  0.461498  0.170            0.0  ...  0.461498      0.460      0.002
# 2016-10-03  0.477553  0.207            4.3  ...  0.477553      0.476      0.002
# 2016-10-04  0.442310  0.195            0.0  ...  0.442310      0.441      0.002
# 2016-10-05  0.409667  0.163            0.0  ...  0.409667      0.408      0.002
#
# [5 rows x 17 columns]

# %% [markdown]
# # Define the model

# %%
def step_zone(z: Zone, s: float, d: ForcingData) ->
