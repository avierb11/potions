# %% [markdown]
# # Load database components

# %% [markdown]
# The purpose of this notebook is to load the database components into Python objects by converting the text objects into a real Python object.

# %%
import os
import pandas as pd
from pandas import DataFrame
import potions as pt

# %%
def get_file_contents(file_name: str) -> str:
    """
    Load the contents from one of the files
    """
    base_path: str = "./database_components"
    file_path: str = os.path.join(base_path, f"{file_name}.txt")

    with open(file_path, "r") as f:
        return f.read()

# %% [markdown]
# # Temperatures and Debye-Huckel Parameters

# %%
dh_str: str = get_file_contents("temperature_dh_points")

# %%
dh_df: DataFrame = pd.read_csv(
    "./database_components/temperature_dh_points.txt",
    sep="\\s+",
)
dh_df.head()
dh_df.rename(columns={c: c.strip("'") for c in dh_df.columns}, inplace=True)
dh_df = dh_df.drop(columns="temperature").set_index("points").T
dh_df = dh_df.rename(columns={c: c.strip("'") for c in dh_df.columns})
dh_df.index.name = "temperature"
dh_df
# Out:
# points          adh     bdh     bdt
# temperature
# 0.           0.4939  0.3253  0.0374
# 25.          0.5114  0.3288  0.0410
# 60.          0.5465  0.3346  0.0440
# 100.         0.5995  0.3421  0.0460
# 150.         0.6855  0.3525  0.0470
# 200.         0.7994  0.3639  0.0470
# 250.         0.9593  0.3766  0.0340
# 300.         1.2180  0.3925  0.0000

# %% [markdown]
# # Primary Species
#
# The primary species are the main species that the model tracks for both reactions and mass transport

# %%
primary_lines: list[str] = get_file_contents("primary_species").splitlines()
primary_species: dict[str, pt.PrimaryAqueousSpecies] = {}
for primary_line in primary_lines:
    tokens: list[str] = primary_line.split()
    name: str = tokens[0].strip("'")
    dh_size_param: float = float(tokens[1])
    charge: float = float(tokens[2])
    molar_mass: float = float(tokens[3])
    primary_species[name] = pt.PrimaryAqueousSpecies(
        name=name, molar_mass=molar_mass, charge=charge, dh_size_param=dh_size_param
    )
print(f"Number of primary aqueous species: {len(primary_species)}")
# Out:
# Number of primary aqueous species: 100

# %% [markdown]
# # Secondary Species

# %% [markdown]
# The secondary species are controlled by equilibrium reactions, and their structure in the database is as follows:
#
# - Name
# - Number of stoichiometric species
# - Stoichiometry
# - Equilibrium constants at 8 temperatures
# - Debye-Huckel size parameter
# - Charge
# - Molar mass

# %%
secondary_lines: list[str] = get_file_contents("secondary_species").splitlines()
secondary_species: dict[str, pt.SecondarySpecies] = {}
for secondary_line in secondary_lines:
    tokens: list[str] = secondary_line.split()
    name, rest = tokens[0].strip("'"), tokens[1:]
    num_stoich, rest = int(rest[0]), rest[1:]
    stoich_tokens, rest = rest[0 : 2 * num_stoich], rest[2 * num_stoich :]
    eq_const_tokens, rest = rest[0:8], rest[8:]
    dh_size_param, rest = float(rest[0]), rest[1:]
    charge, rest = float(rest[0]), rest[1:]
    molar_mass, rest = float(rest[0]), rest[1:]

    stoich: dict[str, float] = {
        x.strip("'"): float(y) for x, y in zip(stoich_tokens[1::2], stoich_tokens[::2])
    }
    eq_consts: list[float] = [float(x) for x in eq_const_tokens]
    secondary_species[name] = pt.SecondarySpecies(
        name=name,
        stoichiometry=stoich,
        eq_consts=eq_consts,
        dh_size_param=dh_size_param,
        charge=charge,
        molar_mass=molar_mass,
    )

# %%
secondary_species["CO2(aq)"]
# Out:
# SecondarySpecies(name='CO2(aq)', stoichiometry={'H2O': -1.0, 'H+': 1.0, 'HCO3-': 1.0}, eq_consts=[-6.5804, -6.3447, -6.2684, -6.3882, -6.7235, -7.1969, -7.7868, -8.528], dh_size_param=3.0, charge=0.0, molar_mass=44.0098)

# %% [markdown]
# # Mineral species
#
# - Name
# - Molar volume in cm^3/mol
# - Number of stoichiometric species
# - Stoichiometry
# - Equilibrium constants at 8 temperatures
# - Molar mass in g/mol

# %%
mineral_lines: list[str] = get_file_contents("mineral_species").splitlines()
mineral_species: dict[str, pt.MineralSpecies] = {}
for mineral_line in mineral_lines:
    tokens: list[str] = mineral_line.split()
    name, rest = tokens[0].strip("'"), tokens[1:]
    molar_volume, rest = float(rest[0]), rest[1:]
    try:
        num_stoich, rest = int(rest[0]), rest[1:]
    except Exception as e:
        print(name)
        raise e
    stoich_tokens, rest = rest[0 : 2 * num_stoich], rest[2 * num_stoich :]
    eq_const_tokens, rest = rest[0:8], rest[8:]
    molar_mass, rest = float(rest[0]), rest[1:]
    stoich: dict[str, float] = {
        x.strip("'"): float(y) for x, y in zip(stoich_tokens[1::2], stoich_tokens[::2])
    }
    eq_consts: list[float] = [float(x) for x in eq_const_tokens]
    mineral_species[name] = pt.MineralSpecies(
        name=name,
        molar_volume=molar_volume,
        stoichiometry=stoich,
        eq_consts=eq_consts,
        molar_mass=molar_mass,
    )

# %% [markdown]
# # Mineral kinetics

# %% [markdown]
# The mineral kinetic reactions are annoying because they do not follow a good structure. They are really in an annoying, non-computer readable format. Note: I am ignoring all reactions of type "irreversible", because we have never used these in BioRT.

# %%
kinetic_section_lines = get_file_contents("mineral_kinetic_parameters").splitlines()
kinetic_sections: list[list[str]] = []
while len(kinetic_section_lines) > 0:
    if kinetic_section_lines[0].startswith("+---"):
        kinetic_section_lines.pop(0)
    else:
        section: list[str] = []
        while not kinetic_section_lines[0].startswith("+---"):
            section.append(kinetic_section_lines.pop(0))

        kinetic_sections.append(section)

tst_sections: list[list[str]] = []
monod_sections: list[list[str]] = []

for section in kinetic_sections:
    for line in section:
        if line in section:
            if "type" in line:
                if "monod" in line:
                    monod_sections.append(section)
                    break
                elif "tst" in line:
                    tst_sections.append(section)
                    break
                else:
                    break

# Convert the TST sections
tst_reactions: dict[str, dict[str, pt.TstReaction]] = {}
for section in tst_sections:
    name: str = section[0].strip()
    data_lines = section[1:]
    label: str = ""
    rate: float = -999
    dependence: dict[str, float] = {}
    for line in data_lines:
        if "label" in line:
            label = line.split("=")[1].strip()
        elif "dependence" in line:
            dep_tokens: list[str] = line.split(":")
            if len(dep_tokens) > 1:
                dep_str = dep_tokens[1]
                dep_tokens: list[str] = dep_str.split()
                for species_name, dep_coeff in zip(dep_tokens[::2], dep_tokens[1::2]):
                    dependence[species_name] = float(dep_coeff)
        elif "rate(25C)" in line:
            rate: float = float(line.split()[2])

    rxn = pt.TstReaction(
        mineral_name=name, label=label, dependence=dependence, rate_constant=rate
    )

    if name in tst_reactions:
        tst_reactions[name][label] = rxn
    else:
        tst_reactions[name] = {label: rxn}


# Convert the Monod sections
monod_reactions: dict[str, dict[str, pt.MonodReaction]] = {}
for section in monod_sections:
    name: str = section[0].strip()
    data_lines = section[1:]
    label: str = ""
    rate: float = -999
    monod_const: dict[str, float] = {}
    inhib_const: dict[str, float] = {}
    for line in data_lines:
        if "label" in line:
            label = line.split("=")[1].strip()
        elif "monod_terms" in line:
            dep_tokens: list[str] = line.split(":")[1].split()
            for species_name, dep_coeff in zip(dep_tokens[::2], dep_tokens[1::2]):
                monod_const[species_name] = float(dep_coeff)
        elif "inhib_terms" in line:
            dep_tokens: list[str] = line.split(":")[1].split()
            for species_name, dep_coeff in zip(dep_tokens[::2], dep_tokens[1::2]):
                inhib_const[species_name] = float(dep_coeff)
        elif "rate(25C)" in line:
            rate: float = float(line.split()[2])

    rxn = pt.MonodReaction(
        mineral_name=name,
        label=label,
        monod_terms=monod_const,
        inhib_terms=inhib_const,
        rate_constant=rate,
    )

    if name in monod_reactions:
        monod_reactions[name][label] = rxn
    else:
        monod_reactions[name] = {label: rxn}

# %%
print(tst_reactions["Calcite"]["h+"])
print(monod_reactions["SOC"])
# Out:
# TstReaction(mineral_name='Calcite', label='h+', rate_constant=-3.0, dependence={'H+': 1.0})
# {'konza': MonodReaction(mineral_name='SOC', label='konza', rate_constant=-12.6, monod_terms={'SOC': 6e-10}, inhib_terms={})}

# %% [markdown]
# # Exchange reactions

# %%
exchange_lines: list[str] = get_file_contents("exchange_species").splitlines()
exchange_reactions: dict[str, pt.ExchangeReaction] = {}

for line in exchange_lines:
    tokens: list[str] = line.split()
    name, rest = tokens[0].strip("'"), tokens[1:]
    num_stoich, rest = int(rest[0]), rest[1:]
    stoich_tokens, rest = rest[:2*num_stoich], rest[2*num_stoich:]
    dh_size_param, rest = float(rest[0]), rest[1:]
    charge = float(rest[0])

    stoich: dict[str, float] = {}
    for stoich_coeff, spec_name in zip(stoich_tokens[::2], stoich_tokens[1::2]):
        stoich[spec_name.strip("'")] = float(stoich_coeff)

    exchange_reactions[name] = pt.ExchangeReaction(
        name=name,
        stoichiometry=stoich,
        dh_size_param=dh_size_param,
        charge=charge
    )

print(f"Number of exchange species: {exchange_reactions}")
exchange_reactions["XDOC"]
# Out:
# Number of exchange species: {'XDOC': ExchangeReaction(name='XDOC', stoichiometry={'X-': 1.0, 'DOC': 1.0}, dh_size_param=-2.75, charge=0.0), 'NaX': ExchangeReaction(name='NaX', stoichiometry={'Na+': 1.0, 'X-': 1.0}, dh_size_param=-2.2, charge=0.0), 'KX': ExchangeReaction(name='KX', stoichiometry={'K+': 1.0, 'X-': 1.0}, dh_size_param=-0.48, charge=0.0), 'CaX2': ExchangeReaction(name='CaX2', stoichiometry={'Ca++': 1.0, 'X-': 2.0}, dh_size_param=-2.6, charge=0.0), 'MgX2': ExchangeReaction(name='MgX2', stoichiometry={'Mg++': 1.0, 'X-': 2.0}, dh_size_param=-2.6, charge=0.0), 'NH4X': ExchangeReaction(name='NH4X', stoichiometry={'NH4+': 1.0, 'X-': 1.0}, dh_size_param=-0.48, charge=0.0), 'NaXhan_zach1': ExchangeReaction(name='NaXhan_zach1', stoichiometry={'Na+': 1.0, 'Xhan_zach1-': 1.0}, dh_size_param=6.76, charge=0.0), 'NaXhan_zach2': ExchangeReaction(name='NaXhan_zach2', stoichiometry={'Na+': 1.0, 'Xhan_zach2-': 1.0}, dh_size_param=2.2, charge=0.0), 'CsXhan_zach1': ExchangeReaction(name='CsXhan_zach1', stoichiometry={'Cs+': 1.0, 'Xhan_zach1-': 1.0}, dh_size_param=0.0, charge=0.0), 'CsXhan_zach2': ExchangeReaction(name='CsXhan_zach2', stoichiometry={'Cs+': 1.0, 'Xhan_zach2-': 1.0}, dh_size_param=0.0, charge=0.0), 'NaXhan1': ExchangeReaction(name='NaXhan1', stoichiometry={'Na+': 1.0, 'Xhan1a-': 1.0}, dh_size_param=6.99, charge=0.0), 'NaXhan2': ExchangeReaction(name='NaXhan2', stoichiometry={'Na+': 1.0, 'Xhan2a-': 1.0}, dh_size_param=2.34, charge=0.0), 'CsXhan1': ExchangeReaction(name='CsXhan1', stoichiometry={'Cs+': 1.0, 'Xhan1a-': 1.0}, dh_size_param=0.0, charge=0.0), 'CsXhan2': ExchangeReaction(name='CsXhan2', stoichiometry={'Cs+': 1.0, 'Xhan2a-': 1.0}, dh_size_param=0.0, charge=0.0), 'NaXhan3': ExchangeReaction(name='NaXhan3', stoichiometry={'Na+': 1.0, 'Xhan3-': 1.0}, dh_size_param=1.906, charge=0.0), 'KXhan1': ExchangeReaction(name='KXhan1', stoichiometry={'K+': 1.0, 'Xhan1-': 1.0}, dh_size_param=5.034, charge=0.0), 'KXhan2': ExchangeReaction(name='KXhan2', stoichiometry={'K+': 1.0, 'Xhan2-': 1.0}, dh_size_param=2.287, charge=0.0), 'KXhan3': ExchangeReaction(name='KXhan3', stoichiometry={'K+': 1.0, 'Xhan3-': 1.0}, dh_size_param=1.05, charge=0.0), 'Ca0.5Xhan1': ExchangeReaction(name='Ca0.5Xhan1', stoichiometry={'Ca++': 0.5, 'Xhan1-': 1.0}, dh_size_param=7.906, charge=0.0), 'Ca0.5Xhan2': ExchangeReaction(name='Ca0.5Xhan2', stoichiometry={'Ca++': 0.5, 'Xhan2-': 1.0}, dh_size_param=5.202, charge=0.0), 'Ca0.5Xhan3': ExchangeReaction(name='Ca0.5Xhan3', stoichiometry={'Ca++': 0.5, 'Xhan3-': 1.0}, dh_size_param=1.764, charge=0.0), 'CsXhan3': ExchangeReaction(name='CsXhan3', stoichiometry={'Cs+': 1.0, 'Xhan3-': 1.0}, dh_size_param=0.0, charge=0.0), 'Ca-XB8814-1': ExchangeReaction(name='Ca-XB8814-1', stoichiometry={'Ca++': 1.0, 'XB8814-1': 2.0}, dh_size_param=4.0, charge=0.0), 'Ca-XB8814-2': ExchangeReaction(name='Ca-XB8814-2', stoichiometry={'Ca++': 1.0, 'XB8814-2': 2.0}, dh_size_param=2.0, charge=0.0), 'Ca-XB8814-3': ExchangeReaction(name='Ca-XB8814-3', stoichiometry={'Ca++': 1.0, 'XB8814-3': 2.0}, dh_size_param=1.0, charge=0.0), 'Na-XB8814-1': ExchangeReaction(name='Na-XB8814-1', stoichiometry={'Na+': 1.0, 'XB8814-1': 1.0}, dh_size_param=4.0, charge=0.0), 'Na-XB8814-2': ExchangeReaction(name='Na-XB8814-2', stoichiometry={'Na+': 1.0, 'XB8814-2': 1.0}, dh_size_param=2.0, charge=0.0), 'Na-XB8814-3': ExchangeReaction(name='Na-XB8814-3', stoichiometry={'Na+': 1.0, 'XB8814-3': 1.0}, dh_size_param=1.0, charge=0.0), 'Sr-XB8814-1': ExchangeReaction(name='Sr-XB8814-1', stoichiometry={'Sr++': 1.0, 'XB8814-1': 2.0}, dh_size_param=0.0, charge=0.0), 'Sr-XB8814-2': ExchangeReaction(name='Sr-XB8814-2', stoichiometry={'Sr++': 1.0, 'XB8814-2': 2.0}, dh_size_param=0.0, charge=0.0), 'Sr-XB8814-3': ExchangeReaction(name='Sr-XB8814-3', stoichiometry={'Sr++': 1.0, 'XB8814-3': 2.0}, dh_size_param=0.0, charge=0.0), 'Ca-XWolery': ExchangeReaction(name='Ca-XWolery', stoichiometry={'Ca++': 1.0, 'XWolery': 2.0}, dh_size_param=-2.0, charge=0.0), 'Na-XWolery': Exchang ...
# ExchangeReaction(name='XDOC', stoichiometry={'X-': 1.0, 'DOC': 1.0}, dh_size_param=-2.75, charge=0.0)

# %% [markdown]
# # Constructing the database

# %%
db = pt.ChemicalDatabase(
    primary_species=primary_species,
    secondary_species=secondary_species,
    mineral_species=mineral_species,
    tst_reactions=tst_reactions,
    monod_reactions=monod_reactions,
    exchange_reactions=exchange_reactions,
)

# %% [markdown]
# # Saving and loading the database from a file

# %%
import json
from dataclasses import asdict

# %%
json_str = json.dumps(asdict(db), indent=2)
with open("chemical_database.json", "w") as f:
    f.write(json_str)

# %%
with open("chemical_database.json", "r") as f:
    raw_dict: dict = json.load(f)

# %%
raw_dict.keys()
# Out:
# dict_keys(['primary_species', 'secondary_species', 'mineral_species', 'exchange_reactions', 'tst_reactions', 'monod_reactions'])

# %%
primary_dict: dict = raw_dict["primary_species"]
secondary_dict: dict = raw_dict["secondary_species"]
mineral_dict: dict = raw_dict["mineral_species"]
tst_dict: dict = raw_dict["tst_reactions"]
monod_dict: dict = raw_dict["monod_reactions"]
exchange_dict: dict = raw_dict["exchange_reactions"]

# %%
primary_dict.keys
# Out:
# <function dict.keys()>

# %%
primary_species: dict[str, pt.PrimaryAqueousSpecies] = {
    key: pt.PrimaryAqueousSpecies(**vals) for key, vals in primary_dict.items()
}
secondary_species: dict[str, pt.SecondarySpecies] = {
    key: pt.SecondarySpecies(**vals) for key, vals in secondary_dict.items()
}
mineral_species: dict[str, pt.MineralSpecies] = {
    key: pt.MineralSpecies(**vals) for key, vals in mineral_dict.items()
}
exchange_reactions: dict[str, pt.ExchangeReaction] = {
    key: pt.ExchangeReaction(**vals) for key, vals in exchange_dict.items()
}

tst_reactions: dict[str, dict[str, pt.TstReaction]] = {}
for key, val in tst_dict.items():
    tst_reactions[key] = {
        label: pt.TstReaction(**params) for label, params in val.items()
    }

monod_reactions: dict[str, dict[str, pt.MonodReaction]] = {}
for key, val in monod_dict.items():
    monod_reactions[key] = {
        label: pt.MonodReaction(**params) for label, params in val.items()
    }

# %%
new_db = pt.ChemicalDatabase(
    primary_species=primary_species,
    secondary_species=secondary_species,
    mineral_species=mineral_species,
    tst_reactions=tst_reactions,
    monod_reactions=monod_reactions,
    exchange_reactions=exchange_reactions
)
